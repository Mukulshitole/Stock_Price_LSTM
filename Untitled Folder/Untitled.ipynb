# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from pandas_datareader import data
import yfinance as yf
from sklearn.preprocessing import MinMaxScaler
from keras.layers import Dense, Dropout, LSTM
from keras.models import Sequential
# Out:
# WARNING:tensorflow:From C:\Users\Mukul\anaconda3\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
# Download Apple stock data
Apple = yf.download("AAPL", start="2010-01-01", end="2023-01-01")
df = yf.download("AAPL", start="2010-01-01", end="2023-01-01")
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed

# %%
# Reset index to make 'Date' a regular column
df = df.reset_index()

# %%
# Drop unnecessary columns
df = df.drop(['Date', 'Adj Close'], axis=1)

# %%
# Plot closing prices
plt.plot(df.Close)
plt.title('Apple Stock Closing Prices')
plt.xlabel('Date')
plt.ylabel('Closing Price')
plt.show()

# %%
# Calculate moving averages
ma100 = df.Close.rolling(100).mean()
ma200 = df.Close.rolling(200).mean()

# %%
# Plot closing prices with moving averages
plt.figure(figsize=(12, 6))
plt.plot(df.Close, label='Closing Price')
plt.plot(ma100, 'r', label='MA 100')
plt.plot(ma200, 'g', label='MA 200')
plt.title('Apple Stock Closing Prices with Moving Averages')
plt.xlabel('Date')
plt.ylabel('Price')
plt.legend()
plt.show()

# %%
# Prepare data for LSTM
data_training = pd.DataFrame(df['Close'][0:int(len(df) * 0.70)])
scaler = MinMaxScaler(feature_range=(0, 1))
data_training_array = scaler.fit_transform(data_training)

x_train = []
y_train = []

for i in range(100, data_training_array.shape[0]):
    x_train.append(data_training_array[i - 100:i])
    y_train.append(data_training_array[i, 0])

x_train, y_train = np.array(x_train), np.array(y_train)

# %%
# Build LSTM model
model = Sequential()
model.add(LSTM(units=50, activation='relu', return_sequences=True, input_shape=(x_train.shape[1], 1)))
model.add(Dropout(0.2))
model.add(LSTM(units=60, activation='relu', return_sequences=True))
model.add(Dropout(0.3))
model.add(LSTM(units=80, activation='relu', return_sequences=True))
model.add(Dropout(0.4))
model.add(LSTM(units=120, activation='relu', return_sequences=True))
model.add(Dropout(0.5))
model.add(Dense(units=1))
# Out:
# WARNING:tensorflow:From C:\Users\Mukul\anaconda3\Lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.

# %%
model.summary()

# Compile and train the model
model.compile(optimizer='adam', loss='mean_squared_error')
model.fit(x_train, y_train, epochs=50)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 100, 50)           10400
#
#  dropout (Dropout)           (None, 100, 50)           0
#
#  lstm_1 (LSTM)               (None, 100, 60)           26640
#
#  dropout_1 (Dropout)         (None, 100, 60)           0
#
#  lstm_2 (LSTM)               (None, 100, 80)           45120
#
#  dropout_2 (Dropout)         (None, 100, 80)           0
#
#  lstm_3 (LSTM)               (None, 100, 120)          96480
#
#  dropout_3 (Dropout)         (None, 100, 120)          0
#
#  dense (Dense)               (None, 100, 1)            121
#
# =================================================================
# Total params: 178761 (698.29 KB)
# Trainable params: 178761 (698.29 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# WARNING:tensorflow:From C:\Users\Mukul\anaconda3\Lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# Epoch 1/50
# WARNING:tensorflow:From C:\Users\Mukul\anaconda3\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# 69/69 [==============================] - 22s 212ms/step - loss: 0.0694
# Epoch 2/50
# 69/69 [==============================] - 14s 207ms/step - loss: 0.0551
# Epoch 3/50
# 69/69 [==============================] - 15s 210ms/step - loss: 0.0538
# Epoch 4/50
# 69/69 [==============================] - 14s 210ms/step - loss: 0.0536
# Epoch 5/50
# 69/69 [==============================] - 14s 210ms/step - loss: 0.0528
# Epoch 6/50
# 69/69 [==============================] - 15s 212ms/step - loss: 0.0522
# Epoch 7/50
# 69/69 [==============================] - 15s 215ms/step - loss: 0.0519
# Epoch 8/50
# 69/69 [==============================] - 15s 212ms/step - loss: 0.0518
# Epoch 9/50
# 69/69 [==============================] - 14s 209ms/step - loss: 0.0516
# Epoch 10/50
# 69/69 [==============================] - 14s 209ms/step - loss: 0.0514
# Epoch 11/50
# 69/69 [==============================] - 14s 210ms/step - loss: 0.0512
# Epoch 12/50
# 69/69 [==============================] - 14s 210ms/step - loss: 0.0512
# Epoch 13/50
# 69/69 [==============================] - 14s 209ms/step - loss: 0.0511
# Epoch 14/50
# 69/69 [==============================] - 14s 209ms/step - loss: 0.0509
# Epoch 15/50
# 69/69 [==============================] - 14s 210ms/step - loss: 0.0509
# Epoch 16/50
# 69/69 [==============================] - 14s 208ms/step - loss: 0.0507
# Epoch 17/50
# 69/69 [==============================] - 14s 206ms/step - loss: 0.0506
# Epoch 18/50
# 69/69 [==============================] - 14s 206ms/step - loss: 0.0505
# Epoch 19/50
# 69/69 [==============================] - 11s 157ms/step - loss: 0.0505
# Epoch 20/50
# 69/69 [==============================] - 14s 199ms/step - loss: 0.0505
# Epoch 21/50
# 69/69 [==============================] - 16s 229ms/step - loss: 0.0509
# Epoch 22/50
# 69/69 [==============================] - 16s 227ms/step - loss: 0.0504
# Epoch 23/50
# 69/69 [==============================] - 16s 235ms/step - loss: 0.0506
# Epoch 24/50
# 69/69 [==============================] - 17s 242ms/step - loss: 0.0503
# Epoch 25/50
# 69/69 [==============================] - 16s 235ms/step - loss: 0.0505
# Epoch 26/50
# 69/69 [==============================] - 16s 234ms/step - loss: 0.0503
# Epoch 27/50
# 69/69 [==============================] - 16s 236ms/step - loss: 0.0502
# Epoch 28/50
# 69/69 [==============================] - 16s 232ms/step - loss: 0.0501
# Epoch 29/50
# 69/69 [==============================] - 16s 232ms/step - loss: 0.0503
# Epoch 30/50
# 69/69 [==============================] - 16s 229ms/step - loss: 0.0502
# Epoch 31/50
# 69/69 [==============================] - 16s 239ms/step - loss: 0.0501
# Epoch 32/50
# 69/69 [==============================] - 16s 233ms/step - loss: 0.0501
# Epoch 33/50
# 69/69 [==============================] - 16s 235ms/step - loss: 0.0501
# Epoch 34/50
# 69/69 [==============================] - 16s 232ms/step - loss: 0.0502
# Epoch 35/50
# 69/69 [==============================] - 16s 237ms/step - loss: 0.0500
# Epoch 36/50
# 69/69 [==============================] - 16s 239ms/step - loss: 0.0500
# Epoch 37/50
# 69/69 [==============================] - 17s 247ms/step - loss: 0.0500
# Epoch 38/50
# 69/69 [==============================] - 17s 246ms/step - loss: 0.0499
# Epoch 39/50
# 69/69 [==============================] - 17s 239ms/step - loss: 0.0500
# Epoch 40/50
# 69/69 [==============================] - 16s 236ms/step - loss: 0.0500
# Epoch 41/50
# 69/69 [==============================] - 17s 245ms/step - loss: 0.0500
# Epoch 42/50
# 69/69 [==============================] - 17s 249ms/step - loss: 0.0500
# Epoch 43/50
# 69/69 [==============================] - 17s 248ms/step - loss: 0.0499
# Epoch 44/50
# 69/69 [==============================] - 17s 248ms/step - loss: 0.0500
# Epoch 45/50
# 69/69 [==============================] - 17s 248ms/step - loss: 0.0499
# Epoch 46/50
# 69/69 [==============================] - 17s 248ms/step - loss: 0.0499
# Epoch 47/50
# 69/69 [==============================] - 17s 247ms/step - loss: 0.0499
# Epoch 48/50
# 69/69 [==============================] - 17s 248ms/step - loss: 0.0499
# Epoch 49/50
# 69/69 [==============================] - 17s 245ms/step - loss: 0.0499
# Epoch 50/50
# 69/69 [==============================] - 17s 249ms/step - loss: 0.0499
